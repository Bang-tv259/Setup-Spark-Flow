# %%
from pyspark.sql import SparkSession
import pyspark.sql.functions as F 


master_url = "spark://localhost:7077"
driver_host_ip = "host.docker.internal"

# %%
from pyspark.sql import SparkSession

spark = (
    SparkSession.builder.appName("NotebookInDocker")
    .master("spark://master:7077")  
    .config("spark.driver.memory", "4G")
    .config("spark.executor.instances", "2")
    .config("spark.executor.cores", "1")
    .config("spark.executor.memory", "1G")
    .config("spark.hadoop.fs.s3a.endpoint", "http://minio-cs:9990")
    .config("spark.hadoop.fs.s3a.connection.ssl.enabled", "false")
    .config("spark.hadoop.fs.s3a.path.style.access", "true")
    .config("spark.hadoop.fs.s3a.aws.credentials.provider",
            "org.apache.hadoop.fs.s3a.SimpleAWSCredentialsProvider")
    .config("spark.hadoop.fs.s3a.access.key", "minio")
    .config("spark.hadoop.fs.s3a.secret.key", "minio123")
    .config("spark.eventLog.enabled", "true")  
    .config("spark.eventLog.dir", "file:/tmp/spark-events")
    .getOrCreate()
)
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/11/29 19:47:06 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://935c51b39f85:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.7</code></dd>
#               <dt>Master</dt>
#                 <dd><code>spark://master:7077</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>NotebookInDocker</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
data = [
    (1, "Alice", 23),
    (2, "Bob", 30),
    (3, "Charlie", 28)
]

columns = ["id", "name", "age"]

df = spark.createDataFrame(data, columns)
df.show()
# Out:
# +---+-------+---+
# | id|   name|age|
# +---+-------+---+
# |  1|  Alice| 23|
# |  2|    Bob| 30|
# |  3|Charlie| 28|
# +---+-------+---+

# %%
df.write.mode("overwrite").parquet("s3a://corin/corin_test.parquet")
# Out:
# 25/11/29 19:47:44 WARN MetricsConfig: Cannot locate configuration: tried hadoop-metrics2-s3a-file-system.properties,hadoop-metrics2.properties

# %%
df_load = spark.read.parquet("s3a://corin/corin_test.parquet")
df_load.printSchema()
# Out:
# root
#  |-- id: long (nullable = true)
#  |-- name: string (nullable = true)
#  |-- age: long (nullable = true)
